# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math
from scipy import stats
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

from matplotlib.pyplot import gca

# %%
# make a dataframe for ml models and accuracy scores
comparison = pd.DataFrame()

# %%
map={'Models':['Bagging KNN','KNN', 'DecisionTree', 'RandomForest', 'XGBoost', 'GradientBoosting',
       'AdaBoost', 'Gaussian NaiveBayes', 'LogisticRegression'],'Test Accuracy (%)':[92.80,92.05,60.2,82.9,80.8,80.7,42.3, 85.2, 68.7]}

# %%
# create the dataframe from dictonary
comparison = pd.DataFrame.from_dict(map)

# %%
comparison
# Out:
#                 Models  Test Accuracy (%)
# 0          Bagging KNN              92.80
# 1                  KNN              92.05
# 2         DecisionTree              60.20
# 3         RandomForest              82.90
# 4              XGBoost              80.80
# 5     GradientBoosting              80.70
# 6             AdaBoost              42.30
# 7  Gaussian NaiveBayes              85.20
# 8   LogisticRegression              68.70

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

import seaborn as sns

sns.set_style('whitegrid')

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# use plotly to plot the bar chart

fig = make_subplots(rows=1, cols=1)


fig.add_trace(go.Bar(x = comparison['Models'], y = comparison['Test Accuracy (%)']))
fig.update_layout(xaxis_title="Machine Learning Models",
    yaxis_title="Test Accuracy (%)")

fig.show("png")

# %%
# same the bar chart but with different color


import plotly.express as px
data = px.data.gapminder()

data_1 = comparison
fig = px.bar(data_1, x='Models', y='Test Accuracy (%)',
              color='Test Accuracy (%)', height=400)

fig.show("png")

# %% [markdown]
# Below are accuracy and computation time bar charts plotted for basic deep learning model.ipynb and Multi-head CNN model.ipynb.

# %%
# accuracy bar chart for basic DL model and CNN model


fig = make_subplots(rows=1, cols=1)
model_accuracy_scores = [86.82]
model_accuracy_scores_2 = [96.36]


model_set = ['Basic Neural Network model']
model_set_2=['Multi-headed CNN model']
fig.add_trace(go.Bar(x = model_set, y = model_accuracy_scores, name='Basic Neural Network model'))
fig.add_trace(go.Bar(x = model_set_2, y = model_accuracy_scores_2, name='Multi-headed CNN model'))


fig.update_xaxes(title_text="Neural Network Models")

fig.update_yaxes(title_text="Model Test Accuracy (%)", secondary_y=False)
# fig.update_yaxes(title_text="Model Testing Computation Time (s)", secondary_y=True)


fig.show("png")

# %%
# computation time bar chart for basic DL model and CNN model


fig = make_subplots()
speed = [20]
speed_2 = [71]


model_set = ['Basic Neural Network model']
model_set_2=['Multi-headed CNN model']
fig.add_trace(go.Bar(x = model_set, y = speed, name='Basic Neural Network model'))
fig.add_trace(go.Bar(x = model_set_2, y = speed_2, name='Multi-headed CNN model'))


fig.update_xaxes(title_text="Neural Network Models")

fig.update_yaxes(title_text="Model Test Computation Time (s)", secondary_y=False)

fig.show("png")

# %%
# accuracy bar chart for basic DL model and CNN model


fig = make_subplots(rows=1, cols=1)
model_accuracy_scores = [86.82]
model_accuracy_scores_2 = [96.36]
model_accuracy_scores_3 = [99.36]

model_set = ['Basic Neural Network model']
model_set_2=['Multi-headed CNN model']
model_set_3=['CNN-LSTM model']

fig.add_trace(go.Bar(x = model_set, y = model_accuracy_scores, name='Basic Neural Network model'))
fig.add_trace(go.Bar(x = model_set_2, y = model_accuracy_scores_2, name='Multi-headed CNN model'))
fig.add_trace(go.Bar(x = model_set_3, y = model_accuracy_scores_3, name='CNN-LSTM model'))



fig.update_xaxes(title_text="Neural Network Models")

fig.update_yaxes(title_text="Model Test Accuracy (%)", secondary_y=False)
# fig.update_yaxes(title_text="Model Testing Computation Time (s)", secondary_y=True)


fig.show("png")

# %%
# computation time bar chart for basic DL model and CNN model


fig = make_subplots()
speed = [20]
speed_2 = [71]
speed_3 = [7]


model_set = ['Basic Neural Network model']
model_set_2=['Multi-headed CNN model']
model_set_3=['CNN-LSTM model']

fig.add_trace(go.Bar(x = model_set, y = speed, name='Basic Neural Network model'))
fig.add_trace(go.Bar(x = model_set_2, y = speed_2, name='Multi-headed CNN model'))
fig.add_trace(go.Bar(x = model_set_3, y = speed_3, name='CNN-LSTM model'))



fig.update_xaxes(title_text="Neural Network Models")

fig.update_yaxes(title_text="Model Test Computation Time (s)", secondary_y=False)

fig.show("png")
